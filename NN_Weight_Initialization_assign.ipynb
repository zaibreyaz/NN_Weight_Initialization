# %% [markdown]
# ### Part 1: Understanding Weight initialization

# %%
"""1. Explain the importance of weight initialization in artificial neural networks. Why is it necessary to initialze the weights carefully?
    Ans: Weight initialization is crucial in artificial neural networks as it sets the starting values for the model's weights. Careful initialization 
          ensures that the network begins training with reasonable weights, preventing issues like vanishing/exploding gradients. 
          Proper initialization improves convergence and overall performance during training.

2. Describe the challenges associated with improper weight initialization. How do these issues affect model training and convergence?
    Ans:  Improper weight initialization can lead to challenges like vanishing or exploding gradients. Vanishing gradients make the network hard to 
          train as updates become negligible, while exploding gradients cause instability and divergence. Both issues hinder model convergence, 
          resulting in slow learning or failure to learn altogether.

3. Discuss the concept of variance and how it relates to weight initialization. Why is it crucial to consider the variance of weights during initialization?
    Ans: Variance in weight initialization refers to the spread or range of weight values. Proper initialization adjusts the variance to ensure that the 
          weights are not too large or too small, allowing gradients to flow well during training. Balancing the variance is crucial for stable and 
            effective learning in neural networks."""

# %% [markdown]
# ### Part 2: Weight Initialization Techniques

# %%
"""4. Explain the concept of zero initialization. Discuss its potential limitations and when it can be appropriate to use.
    Ans: Zero initialization sets all the weights in a neural network to zero initially. However, this approach has limitations as all 
          neurons learn the same features, and symmetry-breaking is absent, leading to poor learning. Zero initialization can be suitable 
          for biases in certain cases, but it's generally not recommended for weights in hidden layers.

5. Describe the process of random initialization. How can random initialization be adjusted to mitigate potential issues like saturation or vanishing/exploding gradients? 
    Ans: Random initialization sets weights to random values within a defined range. To mitigate saturation or vanishing/exploding gradients, 
          use appropriate variance adjustment. For example, in Xavier initialization, scale weights based on the number of input and output units 
          to maintain a balance between activations and gradients during training.

6. Discuss the concept of Xavier/Glorot initialization. Explain how it addresses the challenges of improper weight initialization and the underlying theory behind it. 
    Ans: Xavier/Glorot initialization is a weight initialization technique that sets weights using a carefully chosen variance. It balances the initialization to avoid 
          vanishing/exploding gradients during training. The theory is based on ensuring the variance of activations and gradients remains consistent across layers, 
          leading to more stable and efficient learning in neural networks.

7. Explain the concept of He initialization. How does it differ from Xavier initialization, and when is it preferred?
    Ans: He initialization is a weight initialization method optimized for ReLU activation functions. It sets weights with higher variance, 
          helping ReLU neurons to overcome vanishing gradients and learn better. Unlike Xavier, it uses variance based solely on the number of input units, 
          making it suitable for deeper networks with ReLU activations."""

# %% [markdown]
# ### Part 3: Applying Weight initialization

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Dense, Flatten


def model(INITIALIZER, AF):
    # loading dataset
    (X_train_full, y_train_full), (X_test, y_test) = mnist.load_data()

    # Scale the data between 0 to 1 by dividing it by 255. as its an unsigned data between 0-255 range
    X_valid, X_train = X_train_full[:5000] / 255., X_train_full[5000:] / 255.
    y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

    # scale the test set as well
    X_test = X_test / 255.
    model = tf.keras.models.Sequential()
    model.add(Flatten(input_shape=[28, 28], name="inputLayer"))
    model.add(Dense(300, activation=AF, name="hiddenLayer1",kernel_initializer=INITIALIZER))
    model.add(Dense(100, activation=AF, name="hiddenLayer2",kernel_initializer=INITIALIZER))
    model.add(Dense(10, activation="softmax", name="outputLayer"))

    model.compile(loss='sparse_categorical_crossentropy',
                optimizer='adam',
                metrics=["accuracy"])
    model.fit(X_train, y_train, epochs=25,
                    validation_data=(X_valid, y_valid), batch_size=1000)
    
    return max(model.history.history['val_accuracy'])

# %%
# 8. Implement different weight initialization techniques (zero initialization, random initialization, Xavier initialization, and He initialization) in a neural network using a framework of your choice. Train the model on a suitable dataset and compare the performance of the initialized models. 

initializers = {
    'zero_initializers' : model(tf.keras.initializers.Zeros(), 'relu'),
    'random_Uniform_initializers' : model(tf.keras.initializers.RandomUniform(minval=0., maxval=1.), 'relu'),
    'random_Normal_initializers' : model(tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.05, seed=None), 'relu'),
    'Xavier_Normal_initializers' : model(tf.keras.initializers.GlorotNormal(seed=None), 'tanh'),
    'Xavier_Uniform_initializers' : model(tf.keras.initializers.GlorotUniform(seed=None), 'tanh'),
    'He_Normal_initializers' : model(tf.keras.initializers.HeNormal(), 'relu'),
    'He_Uniform_initializers' : model(tf.keras.initializers.HeUniform(), 'relu')
}
print('\n\n\n')
for i,j in initializers.items():
    print(f'{i} : {j}')
# Out:
# Epoch 1/25
# 55/55 [==============================] - 8s 78ms/step - loss: 2.3022 - accuracy: 0.1110 - val_loss: 2.3016 - val_accuracy: 0.1126
# Epoch 2/25
# 55/55 [==============================] - 3s 61ms/step - loss: 2.3016 - accuracy: 0.1123 - val_loss: 2.3012 - val_accuracy: 0.1126
# Epoch 3/25
# 55/55 [==============================] - 3s 60ms/step - loss: 2.3014 - accuracy: 0.1123 - val_loss: 2.3010 - val_accuracy: 0.1126
# Epoch 4/25
# 55/55 [==============================] - 3s 56ms/step - loss: 2.3013 - accuracy: 0.1123 - val_loss: 2.3009 - val_accuracy: 0.1126
# Epoch 5/25
# 55/55 [==============================] - 3s 59ms/step - loss: 2.3012 - accuracy: 0.1123 - val_loss: 2.3009 - val_accuracy: 0.1126
# Epoch 6/25
# 55/55 [==============================] - 3s 54ms/step - loss: 2.3012 - accuracy: 0.1123 - val_loss: 2.3009 - val_accuracy: 0.1126
# Epoch 7/25
# 55/55 [==============================] - 4s 73ms/step - loss: 2.3012 - accuracy: 0.1123 - val_loss: 2.3009 - val_accuracy: 0.1126
# Epoch 8/25
# 55/55 [==============================] - 4s 79ms/step - loss: 2.3012 - accuracy: 0.1123 - val_loss: 2.3009 - val_accuracy: 0.1126
# Epoch 9/25
# 55/55 [==============================] - 4s 71ms/step - loss: 2.3012 - accuracy: 0.1123 - val_loss: 2.3009 - val_accuracy: 0.1126
# Epoch 10/25
# 55/55 [==============================] - 4s 69ms/step - loss: 2.3012 - accuracy: 0.1123 - val_loss: 2.3009 - val_accuracy: 0.1126
# Epoch 11/25
# 55/55 [==============================] - 5s 85ms/step - loss: 2.3012 - accuracy: 0.1123 - val_loss: 2.3009 - val_accuracy: 0.1126
# Epoch 12/25
# 55/55 [==============================] - 4s 69ms/step - loss: 2.3012 - accuracy: 0.1123 - val_loss: 2.3009 - val_accuracy: 0.1126
# Epoch 13/25
# 55/55 [==============================] - 5s 91ms/step - loss: 2.3012 - accuracy: 0.1123 - val_loss: 2.3009 - val_accuracy: 0.1126
# Epoch 14/25
# 55/55 [==============================] - 3s 56ms/step - loss: 2.3012 - accuracy: 0.1123 - val_loss: 2.3009 - val_accuracy: 0.1126
# Epoch 15/25
# 55/55 [==============================] - 3s 54ms/step - loss: 2.3012 - accuracy: 0.1123 - val_loss: 2.3009 - val_accuracy: 0.1126
# Epoch 16/25
# 55/55 [==============================] - 3s 51ms/step - loss: 2.3012 - accuracy: 0.1123 - val_loss: 2.3009 - val_accuracy: 0.1126
# Epoch 17/25
# 55/55 [==============================] - 3s 52ms/step - loss: 2.3012 - accuracy: 0.1123 - val_loss: 2.3008 - val_accuracy: 0.1126
# Epoch 18/25
# 55/55 [==============================] - 3s 51ms/step - loss: 2.3012 - accuracy: 0.1123 - val_loss: 2.3009 - val_accuracy: 0.1126
# Epoch 19/25
# 55/55 [==============================] - 3s 50ms/step - loss: 2.3012 - accuracy: 0.1123 - val_loss: 2.3009 - val_accuracy: 0.1126
# Epoch 20/25
# 55/55 [==============================] - 3s 52ms/step - loss: 2.3012 - accuracy: 0.1123 - val_loss: 2.3009 - val_accuracy: 0.1126
# Epoch 21/25
# 55/55 [==============================] - 3s 60ms/step - loss: 2.3012 - accuracy: 0.1123 - val_loss: 2.3009 - val_accuracy: 0.1126
# Epoch 22/25
# 55/55 [==============================] - 3s 54ms/step - loss: 2.3012 - accuracy: 0.1123 - val_loss: 2.3009 - val_accuracy: 0.1126
# Epoch 23/25
# 55/55 [==============================] - 3s 57ms/step - loss: 2.3012 - accuracy: 0.1123 - val_loss: 2.3009 - val_accuracy: 0.1126
# Epoch 24/25
# 55/55 [==============================] - 4s 64ms/step - loss: 2.3012 - accuracy: 0.1123 - val_loss: 2.3009 - val_accuracy: 0.1126
# Epoch 25/25
# 55/55 [==============================] - 4s 80ms/step - loss: 2.3012 - accuracy: 0.1123 - val_loss: 2.3009 - val_accuracy: 0.1126
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\initializers\initializers.py:120: UserWarning: The initializer RandomUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# Epoch 1/25
# 55/55 [==============================] - 8s 78ms/step - loss: 4016.1235 - accuracy: 0.1003 - val_loss: 525.5038 - val_accuracy: 0.1066
# Epoch 2/25
# 55/55 [==============================] - 4s 78ms/step - loss: 321.8344 - accuracy: 0.1297 - val_loss: 253.1083 - val_accuracy: 0.1096
# Epoch 3/25
# 55/55 [==============================] - 4s 64ms/step - loss: 327.2818 - accuracy: 0.1381 - val_loss: 184.9986 - val_accuracy: 0.1052
# Epoch 4/25
# 55/55 [==============================] - 3s 61ms/step - loss: 86.6554 - accuracy: 0.3541 - val_loss: 54.8305 - val_accuracy: 0.5962
# Epoch 5/25
# 55/55 [==============================] - 3s 59ms/step - loss: 29.1457 - accuracy: 0.5763 - val_loss: 6.8340 - val_accuracy: 0.7336
# Epoch 6/25
# 55/55 [==============================] - 3s 55ms/step - loss: 5.7800 - accuracy: 0.7609 - val_loss: 5.1695 - val_accuracy: 0.7744
# Epoch 7/25
# 55/55 [==============================] - 3s 55ms/step - loss: 4.8655 - accuracy: 0.7774 - val_loss: 4.1177 - val_accuracy: 0.7982
# Epoch 8/25
# 55/55 [==============================] - 3s 52ms/step - loss: 4.8131 - accuracy: 0.7752 - val_loss: 3.6823 - val_accuracy: 0.8150
# Epoch 9/25
# 55/55 [==============================] - 3s 56ms/step - loss: 4.2517 - accuracy: 0.7900 - val_loss: 3.2941 - val_accuracy: 0.8298
# Epoch 10/25
# 55/55 [==============================] - 3s 53ms/step - loss: 5.3347 - accuracy: 0.7719 - val_loss: 14.3839 - val_accuracy: 0.7700
# Epoch 11/25
# 55/55 [==============================] - 3s 64ms/step - loss: 244.8043 - accuracy: 0.3629 - val_loss: 313.2343 - val_accuracy: 0.0992
# Epoch 12/25
# 55/55 [==============================] - 4s 71ms/step - loss: 218.4470 - accuracy: 0.2767 - val_loss: 374.6399 - val_accuracy: 0.3152
# Epoch 13/25
# 55/55 [==============================] - 5s 88ms/step - loss: 138.5233 - accuracy: 0.3810 - val_loss: 19.8755 - val_accuracy: 0.6840
# Epoch 14/25
# 55/55 [==============================] - 4s 71ms/step - loss: 7.9324 - accuracy: 0.8074 - val_loss: 5.4181 - val_accuracy: 0.8540
# Epoch 15/25
# 55/55 [==============================] - 4s 72ms/step - loss: 5.9591 - accuracy: 0.8392 - val_loss: 5.3307 - val_accuracy: 0.8576
# Epoch 16/25
# 55/55 [==============================] - 4s 68ms/step - loss: 5.1874 - accuracy: 0.8500 - val_loss: 4.7319 - val_accuracy: 0.8656
# Epoch 17/25
# 55/55 [==============================] - 4s 72ms/step - loss: 4.7535 - accuracy: 0.8572 - val_loss: 4.4013 - val_accuracy: 0.8696
# Epoch 18/25
# 55/55 [==============================] - 4s 71ms/step - loss: 4.6640 - accuracy: 0.8545 - val_loss: 4.0596 - val_accuracy: 0.8710
# Epoch 19/25
# 55/55 [==============================] - 4s 70ms/step - loss: 4.2816 - accuracy: 0.8599 - val_loss: 3.8999 - val_accuracy: 0.8726
# Epoch 20/25
# 55/55 [==============================] - 4s 70ms/step - loss: 4.0651 - accuracy: 0.8639 - val_loss: 3.7711 - val_accuracy: 0.8740
# Epoch 21/25
# 55/55 [==============================] - 4s 69ms/step - loss: 3.9558 - accuracy: 0.8657 - val_loss: 3.5941 - val_accuracy: 0.8702
# Epoch 22/25
# 55/55 [==============================] - 4s 74ms/step - loss: 3.8721 - accuracy: 0.8649 - val_loss: 3.4284 - val_accuracy: 0.8814
# Epoch 23/25
# 55/55 [==============================] - 4s 73ms/step - loss: 3.5365 - accuracy: 0.8697 - val_loss: 3.6393 - val_accuracy: 0.8680
# Epoch 24/25
# 55/55 [==============================] - 4s 70ms/step - loss: 4.1569 - accuracy: 0.8518 - val_loss: 3.2274 - val_accuracy: 0.8796
# Epoch 25/25
# 55/55 [==============================] - 4s 69ms/step - loss: 3.3605 - accuracy: 0.8708 - val_loss: 3.4333 - val_accuracy: 0.8668
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\initializers\initializers.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# Epoch 1/25
# 55/55 [==============================] - 8s 77ms/step - loss: 0.6557 - accuracy: 0.8286 - val_loss: 0.2524 - val_accuracy: 0.9272
# Epoch 2/25
# 55/55 [==============================] - 4s 66ms/step - loss: 0.2218 - accuracy: 0.9369 - val_loss: 0.1730 - val_accuracy: 0.9528
# Epoch 3/25
# 55/55 [==============================] - 4s 67ms/step - loss: 0.1608 - accuracy: 0.9540 - val_loss: 0.1400 - val_accuracy: 0.9610
# Epoch 4/25
# 55/55 [==============================] - 4s 72ms/step - loss: 0.1262 - accuracy: 0.9635 - val_loss: 0.1194 - val_accuracy: 0.9686
# Epoch 5/25
# 55/55 [==============================] - 4s 75ms/step - loss: 0.1023 - accuracy: 0.9701 - val_loss: 0.1051 - val_accuracy: 0.9708
# Epoch 6/25
# 55/55 [==============================] - 4s 78ms/step - loss: 0.0828 - accuracy: 0.9759 - val_loss: 0.0904 - val_accuracy: 0.9752
# Epoch 7/25
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0708 - accuracy: 0.9794 - val_loss: 0.0866 - val_accuracy: 0.9738
# Epoch 8/25
# 55/55 [==============================] - 4s 74ms/step - loss: 0.0610 - accuracy: 0.9820 - val_loss: 0.0823 - val_accuracy: 0.9750
# Epoch 9/25
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0500 - accuracy: 0.9859 - val_loss: 0.0733 - val_accuracy: 0.9774
# Epoch 10/25
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0420 - accuracy: 0.9886 - val_loss: 0.0759 - val_accuracy: 0.9778
# Epoch 11/25
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0367 - accuracy: 0.9896 - val_loss: 0.0665 - val_accuracy: 0.9812
# Epoch 12/25
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0313 - accuracy: 0.9917 - val_loss: 0.0677 - val_accuracy: 0.9806
# Epoch 13/25
# 55/55 [==============================] - 4s 72ms/step - loss: 0.0266 - accuracy: 0.9938 - val_loss: 0.0637 - val_accuracy: 0.9822
# Epoch 14/25
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0240 - accuracy: 0.9935 - val_loss: 0.0649 - val_accuracy: 0.9810
# Epoch 15/25
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0197 - accuracy: 0.9955 - val_loss: 0.0630 - val_accuracy: 0.9816
# Epoch 16/25
# 55/55 [==============================] - 4s 73ms/step - loss: 0.0171 - accuracy: 0.9963 - val_loss: 0.0670 - val_accuracy: 0.9806
# Epoch 17/25
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0141 - accuracy: 0.9974 - val_loss: 0.0629 - val_accuracy: 0.9810
# Epoch 18/25
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0122 - accuracy: 0.9978 - val_loss: 0.0641 - val_accuracy: 0.9800
# Epoch 19/25
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0100 - accuracy: 0.9987 - val_loss: 0.0647 - val_accuracy: 0.9814
# Epoch 20/25
# 55/55 [==============================] - 4s 66ms/step - loss: 0.0085 - accuracy: 0.9990 - val_loss: 0.0626 - val_accuracy: 0.9832
# Epoch 21/25
# 55/55 [==============================] - 3s 63ms/step - loss: 0.0072 - accuracy: 0.9992 - val_loss: 0.0677 - val_accuracy: 0.9824
# Epoch 22/25
# 55/55 [==============================] - 4s 66ms/step - loss: 0.0063 - accuracy: 0.9994 - val_loss: 0.0645 - val_accuracy: 0.9816
# Epoch 23/25
# 55/55 [==============================] - 4s 65ms/step - loss: 0.0055 - accuracy: 0.9995 - val_loss: 0.0685 - val_accuracy: 0.9812
# Epoch 24/25
# 55/55 [==============================] - 3s 61ms/step - loss: 0.0046 - accuracy: 0.9998 - val_loss: 0.0652 - val_accuracy: 0.9816
# Epoch 25/25
# 55/55 [==============================] - 3s 57ms/step - loss: 0.0040 - accuracy: 0.9998 - val_loss: 0.0650 - val_accuracy: 0.9822
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\initializers\initializers.py:120: UserWarning: The initializer GlorotNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# Epoch 1/25
# 55/55 [==============================] - 7s 68ms/step - loss: 0.5801 - accuracy: 0.8380 - val_loss: 0.2759 - val_accuracy: 0.9236
# Epoch 2/25
# 55/55 [==============================] - 3s 56ms/step - loss: 0.2635 - accuracy: 0.9250 - val_loss: 0.2178 - val_accuracy: 0.9390
# Epoch 3/25
# 55/55 [==============================] - 3s 59ms/step - loss: 0.2129 - accuracy: 0.9397 - val_loss: 0.1875 - val_accuracy: 0.9490
# Epoch 4/25
# 55/55 [==============================] - 3s 58ms/step - loss: 0.1784 - accuracy: 0.9488 - val_loss: 0.1624 - val_accuracy: 0.9546
# Epoch 5/25
# 55/55 [==============================] - 3s 57ms/step - loss: 0.1528 - accuracy: 0.9563 - val_loss: 0.1438 - val_accuracy: 0.9610
# Epoch 6/25
# 55/55 [==============================] - 3s 54ms/step - loss: 0.1318 - accuracy: 0.9628 - val_loss: 0.1309 - val_accuracy: 0.9620
# Epoch 7/25
# 55/55 [==============================] - 3s 60ms/step - loss: 0.1152 - accuracy: 0.9682 - val_loss: 0.1207 - val_accuracy: 0.9630
# Epoch 8/25
# 55/55 [==============================] - 3s 57ms/step - loss: 0.1013 - accuracy: 0.9714 - val_loss: 0.1097 - val_accuracy: 0.9702
# Epoch 9/25
# 55/55 [==============================] - 3s 59ms/step - loss: 0.0889 - accuracy: 0.9748 - val_loss: 0.1029 - val_accuracy: 0.9712
# Epoch 10/25
# 55/55 [==============================] - 3s 61ms/step - loss: 0.0791 - accuracy: 0.9780 - val_loss: 0.0972 - val_accuracy: 0.9712
# Epoch 11/25
# 55/55 [==============================] - 2s 40ms/step - loss: 0.0699 - accuracy: 0.9807 - val_loss: 0.0914 - val_accuracy: 0.9722
# Epoch 12/25
# 55/55 [==============================] - 1s 21ms/step - loss: 0.0628 - accuracy: 0.9819 - val_loss: 0.0876 - val_accuracy: 0.9740
# Epoch 13/25
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0550 - accuracy: 0.9850 - val_loss: 0.0825 - val_accuracy: 0.9754
# Epoch 14/25
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0496 - accuracy: 0.9869 - val_loss: 0.0822 - val_accuracy: 0.9734
# Epoch 15/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0433 - accuracy: 0.9888 - val_loss: 0.0792 - val_accuracy: 0.9766
# Epoch 16/25
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0386 - accuracy: 0.9906 - val_loss: 0.0777 - val_accuracy: 0.9750
# Epoch 17/25
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0340 - accuracy: 0.9921 - val_loss: 0.0736 - val_accuracy: 0.9768
# Epoch 18/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0305 - accuracy: 0.9931 - val_loss: 0.0723 - val_accuracy: 0.9774
# Epoch 19/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0273 - accuracy: 0.9935 - val_loss: 0.0690 - val_accuracy: 0.9780
# Epoch 20/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0234 - accuracy: 0.9956 - val_loss: 0.0685 - val_accuracy: 0.9786
# Epoch 21/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0213 - accuracy: 0.9957 - val_loss: 0.0682 - val_accuracy: 0.9796
# Epoch 22/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0193 - accuracy: 0.9964 - val_loss: 0.0666 - val_accuracy: 0.9788
# Epoch 23/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0164 - accuracy: 0.9973 - val_loss: 0.0649 - val_accuracy: 0.9794
# Epoch 24/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0143 - accuracy: 0.9981 - val_loss: 0.0636 - val_accuracy: 0.9820
# Epoch 25/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0127 - accuracy: 0.9985 - val_loss: 0.0627 - val_accuracy: 0.9814
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\initializers\initializers.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# Epoch 1/25
# 55/55 [==============================] - 2s 21ms/step - loss: 0.5595 - accuracy: 0.8437 - val_loss: 0.2783 - val_accuracy: 0.9186
# Epoch 2/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2628 - accuracy: 0.9254 - val_loss: 0.2184 - val_accuracy: 0.9366
# Epoch 3/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2091 - accuracy: 0.9407 - val_loss: 0.1831 - val_accuracy: 0.9500
# Epoch 4/25
# 55/55 [==============================] - 1s 19ms/step - loss: 0.1765 - accuracy: 0.9494 - val_loss: 0.1581 - val_accuracy: 0.9564
# Epoch 5/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1482 - accuracy: 0.9578 - val_loss: 0.1395 - val_accuracy: 0.9596
# Epoch 6/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1271 - accuracy: 0.9640 - val_loss: 0.1261 - val_accuracy: 0.9636
# Epoch 7/25
# 55/55 [==============================] - 1s 20ms/step - loss: 0.1121 - accuracy: 0.9685 - val_loss: 0.1152 - val_accuracy: 0.9664
# Epoch 8/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0969 - accuracy: 0.9727 - val_loss: 0.1079 - val_accuracy: 0.9692
# Epoch 9/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0845 - accuracy: 0.9765 - val_loss: 0.0993 - val_accuracy: 0.9708
# Epoch 10/25
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0739 - accuracy: 0.9800 - val_loss: 0.0902 - val_accuracy: 0.9744
# Epoch 11/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0648 - accuracy: 0.9824 - val_loss: 0.0873 - val_accuracy: 0.9754
# Epoch 12/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0575 - accuracy: 0.9845 - val_loss: 0.0856 - val_accuracy: 0.9752
# Epoch 13/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0500 - accuracy: 0.9866 - val_loss: 0.0795 - val_accuracy: 0.9750
# Epoch 14/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0460 - accuracy: 0.9881 - val_loss: 0.0835 - val_accuracy: 0.9736
# Epoch 15/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0411 - accuracy: 0.9894 - val_loss: 0.0744 - val_accuracy: 0.9766
# Epoch 16/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0348 - accuracy: 0.9919 - val_loss: 0.0722 - val_accuracy: 0.9786
# Epoch 17/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0305 - accuracy: 0.9932 - val_loss: 0.0693 - val_accuracy: 0.9774
# Epoch 18/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0266 - accuracy: 0.9944 - val_loss: 0.0695 - val_accuracy: 0.9800
# Epoch 19/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0240 - accuracy: 0.9950 - val_loss: 0.0716 - val_accuracy: 0.9774
# Epoch 20/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0214 - accuracy: 0.9960 - val_loss: 0.0696 - val_accuracy: 0.9794
# Epoch 21/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0181 - accuracy: 0.9972 - val_loss: 0.0678 - val_accuracy: 0.9800
# Epoch 22/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0161 - accuracy: 0.9976 - val_loss: 0.0683 - val_accuracy: 0.9802
# Epoch 23/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0141 - accuracy: 0.9979 - val_loss: 0.0680 - val_accuracy: 0.9804
# Epoch 24/25
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0125 - accuracy: 0.9984 - val_loss: 0.0676 - val_accuracy: 0.9794
# Epoch 25/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0113 - accuracy: 0.9985 - val_loss: 0.0662 - val_accuracy: 0.9800
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\initializers\initializers.py:120: UserWarning: The initializer HeNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# Epoch 1/25
# 55/55 [==============================] - 2s 23ms/step - loss: 0.6380 - accuracy: 0.8233 - val_loss: 0.2445 - val_accuracy: 0.9314
# Epoch 2/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.2153 - accuracy: 0.9381 - val_loss: 0.1674 - val_accuracy: 0.9532
# Epoch 3/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1540 - accuracy: 0.9567 - val_loss: 0.1303 - val_accuracy: 0.9644
# Epoch 4/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1188 - accuracy: 0.9660 - val_loss: 0.1099 - val_accuracy: 0.9696
# Epoch 5/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0973 - accuracy: 0.9722 - val_loss: 0.0962 - val_accuracy: 0.9740
# Epoch 6/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0783 - accuracy: 0.9776 - val_loss: 0.0870 - val_accuracy: 0.9754
# Epoch 7/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0645 - accuracy: 0.9817 - val_loss: 0.0808 - val_accuracy: 0.9768
# Epoch 8/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0536 - accuracy: 0.9849 - val_loss: 0.0763 - val_accuracy: 0.9786
# Epoch 9/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0462 - accuracy: 0.9868 - val_loss: 0.0719 - val_accuracy: 0.9788
# Epoch 10/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0387 - accuracy: 0.9896 - val_loss: 0.0714 - val_accuracy: 0.9780
# Epoch 11/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0325 - accuracy: 0.9915 - val_loss: 0.0705 - val_accuracy: 0.9794
# Epoch 12/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0281 - accuracy: 0.9929 - val_loss: 0.0667 - val_accuracy: 0.9788
# Epoch 13/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0237 - accuracy: 0.9943 - val_loss: 0.0680 - val_accuracy: 0.9798
# Epoch 14/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0203 - accuracy: 0.9955 - val_loss: 0.0675 - val_accuracy: 0.9802
# Epoch 15/25
# 55/55 [==============================] - 1s 14ms/step - loss: 0.0173 - accuracy: 0.9964 - val_loss: 0.0664 - val_accuracy: 0.9820
# Epoch 16/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0142 - accuracy: 0.9975 - val_loss: 0.0661 - val_accuracy: 0.9810
# Epoch 17/25
# 55/55 [==============================] - 1s 15ms/step - loss: 0.0122 - accuracy: 0.9979 - val_loss: 0.0644 - val_accuracy: 0.9824
# Epoch 18/25
# 55/55 [==============================] - 1s 15ms/step - loss: 0.0100 - accuracy: 0.9985 - val_loss: 0.0672 - val_accuracy: 0.9798
# Epoch 19/25
# 55/55 [==============================] - 1s 15ms/step - loss: 0.0084 - accuracy: 0.9989 - val_loss: 0.0663 - val_accuracy: 0.9804
# Epoch 20/25
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0072 - accuracy: 0.9992 - val_loss: 0.0673 - val_accuracy: 0.9820
# Epoch 21/25
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0062 - accuracy: 0.9994 - val_loss: 0.0647 - val_accuracy: 0.9806
# Epoch 22/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0057 - accuracy: 0.9995 - val_loss: 0.0710 - val_accuracy: 0.9790
# Epoch 23/25
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0055 - accuracy: 0.9994 - val_loss: 0.0683 - val_accuracy: 0.9822
# Epoch 24/25
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0041 - accuracy: 0.9997 - val_loss: 0.0684 - val_accuracy: 0.9800
# Epoch 25/25
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0034 - accuracy: 0.9998 - val_loss: 0.0703 - val_accuracy: 0.9806
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\initializers\initializers.py:120: UserWarning: The initializer HeUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# Epoch 1/25
# 55/55 [==============================] - 3s 27ms/step - loss: 0.5963 - accuracy: 0.8379 - val_loss: 0.2387 - val_accuracy: 0.9326
# Epoch 2/25
# 55/55 [==============================] - 1s 19ms/step - loss: 0.2118 - accuracy: 0.9398 - val_loss: 0.1718 - val_accuracy: 0.9528
# Epoch 3/25
# 55/55 [==============================] - 1s 21ms/step - loss: 0.1539 - accuracy: 0.9562 - val_loss: 0.1333 - val_accuracy: 0.9622
# Epoch 4/25
# 55/55 [==============================] - 1s 25ms/step - loss: 0.1199 - accuracy: 0.9657 - val_loss: 0.1123 - val_accuracy: 0.9684
# Epoch 5/25
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0958 - accuracy: 0.9730 - val_loss: 0.1041 - val_accuracy: 0.9714
# Epoch 6/25
# 55/55 [==============================] - 1s 21ms/step - loss: 0.0799 - accuracy: 0.9773 - val_loss: 0.0915 - val_accuracy: 0.9742
# Epoch 7/25
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0661 - accuracy: 0.9814 - val_loss: 0.0796 - val_accuracy: 0.9752
# Epoch 8/25
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0555 - accuracy: 0.9844 - val_loss: 0.0755 - val_accuracy: 0.9764
# Epoch 9/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0465 - accuracy: 0.9869 - val_loss: 0.0717 - val_accuracy: 0.9780
# Epoch 10/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0390 - accuracy: 0.9895 - val_loss: 0.0675 - val_accuracy: 0.9792
# Epoch 11/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0324 - accuracy: 0.9916 - val_loss: 0.0678 - val_accuracy: 0.9808
# Epoch 12/25
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0275 - accuracy: 0.9932 - val_loss: 0.0656 - val_accuracy: 0.9804
# Epoch 13/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0231 - accuracy: 0.9944 - val_loss: 0.0631 - val_accuracy: 0.9816
# Epoch 14/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0199 - accuracy: 0.9958 - val_loss: 0.0636 - val_accuracy: 0.9796
# Epoch 15/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0166 - accuracy: 0.9965 - val_loss: 0.0642 - val_accuracy: 0.9802
# Epoch 16/25
# 55/55 [==============================] - 1s 15ms/step - loss: 0.0147 - accuracy: 0.9969 - val_loss: 0.0658 - val_accuracy: 0.9802
# Epoch 17/25
# 55/55 [==============================] - 1s 15ms/step - loss: 0.0120 - accuracy: 0.9979 - val_loss: 0.0649 - val_accuracy: 0.9818
# Epoch 18/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0108 - accuracy: 0.9983 - val_loss: 0.0649 - val_accuracy: 0.9806
# Epoch 19/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0086 - accuracy: 0.9989 - val_loss: 0.0629 - val_accuracy: 0.9812
# Epoch 20/25
# 55/55 [==============================] - 1s 15ms/step - loss: 0.0071 - accuracy: 0.9992 - val_loss: 0.0662 - val_accuracy: 0.9816
# Epoch 21/25
# 55/55 [==============================] - 1s 15ms/step - loss: 0.0063 - accuracy: 0.9994 - val_loss: 0.0654 - val_accuracy: 0.9814
# Epoch 22/25
# 55/55 [==============================] - 1s 15ms/step - loss: 0.0055 - accuracy: 0.9996 - val_loss: 0.0633 - val_accuracy: 0.9828
# Epoch 23/25
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0047 - accuracy: 0.9997 - val_loss: 0.0660 - val_accuracy: 0.9818
# Epoch 24/25
# 55/55 [==============================] - 1s 15ms/step - loss: 0.0036 - accuracy: 0.9999 - val_loss: 0.0653 - val_accuracy: 0.9816
# Epoch 25/25
# 55/55 [==============================] - 1s 14ms/step - loss: 0.0032 - accuracy: 0.9999 - val_loss: 0.0692 - val_accuracy: 0.9812
#
#
#
#
# zero_initializers : 0.11259999871253967
# random_Uniform_initializers : 0.8813999891281128
# random_Normal_initializers : 0.9832000136375427
# Xavier_Normal_initializers : 0.9819999933242798
# Xavier_Uniform_initializers : 0.980400025844574
# He_Normal_initializers : 0.9824000000953674
# He_Uniform_initializers : 0.9828000068664551

# %% [markdown]
# ### we get the output as:
# - zero_initializers : 0.11259999871253967
# - random_Uniform_initializers : 0.8813999891281128
# - random_Normal_initializers : 0.9832000136375427
# - Xavier_Normal_initializers : 0.9819999933242798
# - Xavier_Uniform_initializers : 0.980400025844574
# - He_Normal_initializers : 0.9824000000953674
# - He_Uniform_initializers : 0.9828000068664551

# %%
"""9. Discuss the considerations and tradeoffs when choosing the appropriate weight initialization technique for a given neural network architecture and task.
    Ans: When choosing a weight initialization technique for a neural network, consider the architecture and task. 
            Xavier/Glorot initialization is good for tanh and sigmoid activations, while He initialization suits ReLU-based activations. 
            Proper initialization helps prevent vanishing/exploding gradients. Experiment with different techniques to find what works best for your specific model and problem.
"""
